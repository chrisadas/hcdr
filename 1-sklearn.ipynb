# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer
from imblearn.over_sampling import SMOTE, ADASYN
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from catboost import CatBoostClassifier
import matplotlib.pyplot as plt
import scikitplot as skplt
import eli5

# %%
def numeric_features(data, category_num_cutoff=10):
    # separate numeric and string column
    data_numeric = data.select_dtypes(exclude=['object'])
    data_string = data.select_dtypes(include=['object'])
    # discard categorical columns with more than category_num_cutoff categories
    for col in data_string:
        if data_string[col].nunique() > category_num_cutoff:
            data_string = data_string.drop(col, axis=1)
    data_string_dummies = pd.get_dummies(data_string, dummy_na=True)
    data_features = pd.concat([data_numeric, data_string_dummies], axis=1)
    return(data_features)

# %%
def application_composite_features(input_data):
    data = input_data.copy()
    data['INCOME_PER_CHILDREN'] = data['AMT_INCOME_TOTAL'] / (data['CNT_CHILDREN'] + 1)
    data['CREDIT_TO_INCOME'] = data['AMT_CREDIT'] / data['AMT_INCOME_TOTAL']
    data['ANNUITY_TO_INCOME'] = data['AMT_ANNUITY'] / data['AMT_INCOME_TOTAL']
    data['CREDIT_TO_ANNUITY'] = data['AMT_CREDIT'] / data['AMT_ANNUITY']
    data['CREDIT_TO_GOODS_PRICE'] = data['AMT_CREDIT'] / data['AMT_GOODS_PRICE']
    data['EXT_SOURCE_MEAN'] = data[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    return(data)

# %% [markdown]
# # Application Data

# %%
app_train = pd.read_csv('application_train.csv.zip')
app_train.shape
# Out:
# (307511, 122)

# %%
app_train_features = numeric_features(app_train)
app_train_features = application_composite_features(app_train_features)
app_train_features.shape
# Out:
# (307511, 190)

# %% [markdown]
# # Credit Bureau Data

# %%
bureau = pd.read_csv('bureau.csv.zip', compression='zip')

# %%
def bureau_get_features(input_data):
    data = input_data.copy()
    data.rename(columns={'AMT_ANNUITY': 'BUREAU_AMT_ANNUITY'}, inplace=True)
    data = data.loc[data['CREDIT_ACTIVE'] == 'Active']
    data = data.select_dtypes(exclude=['object'])
    data = data.groupby('SK_ID_CURR').agg(['min', 'max']).reset_index()
    data.columns = ['_'.join(col) for col in data.columns.values]
    data.rename(columns={'SK_ID_CURR_': 'SK_ID_CURR'}, inplace=True)
    data.drop(['SK_ID_BUREAU_min', 'SK_ID_BUREAU_max'], axis=1, inplace=True)
    return(data)

# %%
bureau_features = bureau_get_features(bureau)

# %%
bureau_balance = pd.read_csv('bureau_balance.csv.zip', compression='zip')

# discard closed [C] and unknown status [X] and convert to integer
bureau_balance = bureau_balance[~bureau_balance['STATUS'].isin(['C', 'X'])]
bureau_balance['STATUS'] = bureau_balance['STATUS'].astype('int')

# %%
bureau_history12m = bureau_balance.loc[bureau_balance['MONTHS_BALANCE'] > -12,
                               ['SK_ID_BUREAU', 'STATUS']].groupby('SK_ID_BUREAU').agg(['count', 'max', 'sum'])
bureau_history12m.columns = ['bureau12m_active_m', 'bureau12m_max_dpd', 'bureau12m_sum_dpd']
bureau_history12m.reset_index(inplace=True)
bureau_history12m = pd.merge(bureau[['SK_ID_CURR', 'SK_ID_BUREAU']], bureau_history12m, on='SK_ID_BUREAU', how='left')
bureau_history12m = bureau_history12m.groupby('SK_ID_CURR').agg('sum').drop(['SK_ID_BUREAU'], axis=1).reset_index()

# %%
bureau_history60m = bureau_balance.loc[bureau_balance['MONTHS_BALANCE'] > -60,
                               ['SK_ID_BUREAU', 'STATUS']].groupby('SK_ID_BUREAU').agg(['count', 'max', 'sum'])
bureau_history60m.columns = ['bureau60m_active_m', 'bureau60m_max_dpd', 'bureau60m_sum_dpd']
bureau_history60m.reset_index(inplace=True)
bureau_history60m = pd.merge(bureau[['SK_ID_CURR', 'SK_ID_BUREAU']], bureau_history60m, on='SK_ID_BUREAU', how='left')
bureau_history60m = bureau_history60m.groupby('SK_ID_CURR').agg('sum').drop(['SK_ID_BUREAU'], axis=1).reset_index()

# %% [markdown]
# # Previous applications data

# %%
previous = pd.read_csv('previous_application.csv.zip', compression='zip')
previous.shape
# Out:
# (1670214, 37)

# %%
previous.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START            ...            NAME_SELLER_INDUSTRY  \
# 0                       15            ...                    Connectivity
# 1                       11            ...                             XNA
# 2                       11            ...                             XNA
# 3                        7            ...                             XNA
# 4                        9            ...                             XNA
#
#    CNT_PAYMENT  NAME_YIELD_GROUP       PRODUCT_COMBINATION  \
# 0         12.0            middle  POS mobile with interest
# 1         36.0        low_action          Cash X-Sell: low
# 2         12.0              high         Cash X-Sell: high
# 3         12.0            middle       Cash X-Sell: middle
# 4         24.0              high         Cash Street: high
#
#    DAYS_FIRST_DRAWING DAYS_FIRST_DUE DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  \
# 0            365243.0          -42.0                     300.0          -42.0
# 1            365243.0         -134.0                     916.0       365243.0
# 2            365243.0         -271.0                      59.0       365243.0
# 3            365243.0         -482.0                    -152.0         -182.0
# 4                 NaN            NaN                       NaN            NaN
#
#   DAYS_TERMINATION NFLAG_INSURED_ON_APPROVAL
# 0            -37.0                       0.0
# 1         365243.0                       1.0
# 2         365243.0                       1.0
# 3           -177.0                       1.0
# 4              NaN                       NaN
#
# [5 rows x 37 columns]

# %%
# order df such that latest records are last
previous.sort_values(['SK_ID_CURR', 'DAYS_DECISION'], ascending=[True, True], inplace=True)

# Keep only lastest record of each current applicants
previous = previous.drop_duplicates(subset=['SK_ID_CURR'], keep='last')

# Add column name prefix to differentiate from current application
previous = previous.add_prefix('PREVAPP_')

# %%
previous.head()
# Out:
#          PREVAPP_SK_ID_PREV  PREVAPP_SK_ID_CURR PREVAPP_NAME_CONTRACT_TYPE  \
# 201668              1369693              100001             Consumer loans
# 892077              1038818              100002             Consumer loans
# 575941              1810518              100003                 Cash loans
# 935548              1564014              100004             Consumer loans
# 1259112             1857999              100005                 Cash loans
#
#          PREVAPP_AMT_ANNUITY  PREVAPP_AMT_APPLICATION  PREVAPP_AMT_CREDIT  \
# 201668              3951.000                  24835.5             23787.0
# 892077              9251.775                 179055.0            179055.0
# 575941             98356.995                 900000.0           1035882.0
# 935548              5357.250                  24282.0             20106.0
# 1259112                  NaN                      0.0                 0.0
#
#          PREVAPP_AMT_DOWN_PAYMENT  PREVAPP_AMT_GOODS_PRICE  \
# 201668                     2520.0                  24835.5
# 892077                        0.0                 179055.0
# 575941                        NaN                 900000.0
# 935548                     4860.0                  24282.0
# 1259112                       NaN                      NaN
#
#         PREVAPP_WEEKDAY_APPR_PROCESS_START  PREVAPP_HOUR_APPR_PROCESS_START  \
# 201668                              FRIDAY                               13
# 892077                            SATURDAY                                9
# 575941                              FRIDAY                               12
# 935548                              FRIDAY                                5
# 1259112                             FRIDAY                               10
#
#                        ...                PREVAPP_NAME_SELLER_INDUSTRY  \
# 201668                 ...                                Connectivity
# 892077                 ...                             Auto technology
# 575941                 ...                                         XNA
# 935548                 ...                                Connectivity
# 1259112                ...                                         XNA
#
#          PREVAPP_CNT_PAYMENT  PREVAPP_NAME_YIELD_GROUP  \
# 201668                   8.0                      high
# 892077                  24.0                low_normal
# 575941                  12.0                low_normal
# 935548                   4.0                    middle
# 1259112                  NaN                       XNA
#
#          PREVAPP_PRODUCT_COMBINATION  PREVAPP_DAYS_FIRST_DRAWING  \
# 201668      POS mobile with interest                    365243.0
# 892077       POS other with interest                    365243.0
# 575941              Cash X-Sell: low                    365243.0
# 935548   POS mobile without interest                    365243.0
# 1259112                         Cash                         NaN
#
#         PREVAPP_DAYS_FIRST_DUE PREVAPP_DAYS_LAST_DUE_1ST_VERSION  \
# 201668                 -1709.0                           -1499.0
# 892077                  -565.0                             125.0
# 575941                  -716.0                            -386.0
# 935548                  -784.0                            -694.0
# 1259112                    NaN                               NaN
#
#          PREVAPP_DAYS_LAST_DUE PREVAPP_DAYS_TERMINATION  \
# 201668                 -1619.0                  -1612.0
# 892077                   -25.0                    -17.0
# 575941                  -536.0                   -527.0
# 935548                  -724.0                   -714.0
# 1259112                    NaN                      NaN
#
#         PREVAPP_NFLAG_INSURED_ON_APPROVAL
# 201668                                0.0
# 892077                                0.0
# 575941                                1.0
# 935548                                0.0
# 1259112                               NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# # Combine data and model

# %%
record = pd.merge(app_train_features, bureau_features, on='SK_ID_CURR', how='left')
record = pd.merge(record, bureau_history12m, on='SK_ID_CURR', how='left')
record = pd.merge(record, bureau_history60m, on='SK_ID_CURR', how='left')
record = pd.merge(record, previous, left_on='SK_ID_CURR', right_on='PREVAPP_SK_ID_CURR', how='left')
record.shape
# Out:
# (307511, 257)

# %%
y = record['TARGET']
X = record.drop(['TARGET', 'SK_ID_CURR'], axis=1)

# %%
# %%time

# Sklearn

X = X.select_dtypes(exclude='object')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

imputer = Imputer(strategy='median')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# X_resampled, y_resampled = SMOTE().fit_sample(X_train_imputed, y_train)

# model = GradientBoostingClassifier(random_state=0, n_estimators=2000)

model = GradientBoostingClassifier(random_state=0)

# model = RandomForestClassifier(random_state=0)

model.fit(X_train_imputed, y_train)


preds_class = model.predict(X_test_imputed)
preds_proba = model.predict_proba(X_test_imputed)
# Out:
# CPU times: user 5min 47s, sys: 2.06 s, total: 5min 49s
# Wall time: 5min 49s

# %%
# Model metrics

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 10))

skplt.metrics.plot_confusion_matrix(y_test, preds_class, ax=ax1)

skplt.metrics.plot_precision_recall(y_test, preds_proba, ax=ax2,
                                    classes_to_plot=[1], plot_micro=False);

skplt.metrics.plot_roc(y_test, preds_proba, classes_to_plot=[1], ax=ax3,
                      plot_micro=False, plot_macro=False);

skplt.metrics.plot_ks_statistic(y_test, preds_proba, ax=ax4);
# Out:
# /home/chris/.local/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
eli5.explain_weights(model, feature_names=X.columns.values, top=15)
# Out:
# Explanation(estimator="GradientBoostingClassifier(criterion='friedman_mse', init=None,\n              learning_rate=0.1, loss='deviance', max_depth=3,\n              max_features=None, max_leaf_nodes=None,\n              min_impurity_decrease=0.0, min_impurity_split=None,\n              min_samples_leaf=1, min_samples_split=2,\n              min_weight_fraction_leaf=0.0, n_estimators=100,\n              presort='auto', random_state=0, subsample=1.0, verbose=0,\n              warm_start=False)", description='\nRandom forest feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='EXT_SOURCE_MEAN', weight=0.160877000548553, std=0.26522050579307516, value=None), FeatureWeight(feature='CREDIT_TO_ANNUITY', weight=0.09517263620734472, std=0.2082681439893397, value=None), FeatureWeight(feature='EXT_SOURCE_3', weight=0.05895221385707438, std=0.1053580136435935, value=None), FeatureWeight(feature='DAYS_BIRTH', weight=0.0459219404452401, std=0.08454647975966889, value=None), FeatureWeight(feature='EXT_SOURCE_2', weight=0.04306205566001985, std=0.0787430235188705, value=None), FeatureWeight(feature='EXT_SOURCE_1', weight=0.03925785107300675, std=0.06971439447899035, value=None), FeatureWeight(feature='DAYS_CREDIT_max', weight=0.033813701892854604, std=0.061833400452332, value=None), FeatureWeight(feature='CODE_GENDER_M', weight=0.033163674348402034, std=0.08388292099078773, value=None), FeatureWeight(feature='AMT_ANNUITY', weight=0.031784754835225686, std=0.06582753086620494, value=None), FeatureWeight(feature='CREDIT_TO_GOODS_PRICE', weight=0.027532565515266064, std=0.059957467444065646, value=None), FeatureWeight(feature='AMT_GOODS_PRICE', weight=0.026866402956312502, std=0.08581105541885978, value=None), FeatureWeight(feature='DAYS_EMPLOYED', weight=0.023139063882389167, std=0.06133065156669349, value=None), FeatureWeight(feature='AMT_CREDIT_SUM_OVERDUE_max', weight=0.02072805703603348, std=0.05017179064158868, value=None), FeatureWeight(feature='DAYS_ID_PUBLISH', weight=0.018184289848434208, std=0.05396579150038859, value=None), FeatureWeight(feature='PREVAPP_CNT_PAYMENT', weight=0.0161180869378229, std=0.0448833048138299, value=None)], remaining=224), decision_tree=None, highlight_spaces=None, transition_features=None)

# %%
eli5.show_prediction(model, X_test_imputed[0], top=10, show_feature_values=True,
                        feature_names=X.columns.values, target_names=['performing', 'default'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=performing
#
# </b>
#
#
#     (probability <b>0.873</b>, score <b>-1.927</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#                 <th style="padding: 0 0.5em 0 1em; text-align: right; border: none;">Value</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.433
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         CREDIT_TO_GOODS_PRICE
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.112
#         </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 99.19%); border: none;">
#                 <td colspan="3" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 25 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.93%); border: none;">
#                 <td colspan="3" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 24 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.037
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_BIRTH
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -13297.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.039
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         NAME_EDUCATION_TYPE_Higher education
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.040
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_CREDIT_max
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -129.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.042
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ANNUITY_TO_INCOME
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.254
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.054
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         AMT_ANNUITY
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             52641.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 98.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.065
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         AMT_CREDIT
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             465457.500
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.129
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         AMT_GOODS_PRICE
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             418500.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.143
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         EXT_SOURCE_3
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.001
#         </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
pd.DataFrame(preds_class).sort_values(0, ascending=False).head()
# Out:
#        0
# 24117  1
# 9392   1
# 26148  1
# 36943  1
# 49605  1

# %%
eli5.show_prediction(model, X_test_imputed[9392], top=10, show_feature_values=True,
                        feature_names=X.columns.values, target_names=['performing', 'default'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=default
#
# </b>
#
#
#     (probability <b>0.604</b>, score <b>0.422</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#                 <th style="padding: 0 0.5em 0 1em; text-align: right; border: none;">Value</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.605
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         EXT_SOURCE_3
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.166
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.292
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         EXT_SOURCE_MEAN
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             0.094
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.220
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         CREDIT_TO_GOODS_PRICE
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.158
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.210
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_ID_PUBLISH
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -200.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.207
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_BIRTH
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -12002.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.67%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.187
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         CREDIT_TO_ANNUITY
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             10.852
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.168
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_CREDIT_max
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -8.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.155
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         AMT_GOODS_PRICE
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             261000.000
#         </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.150
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         DAYS_CREDIT_min
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             -8.000
#         </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 97.16%); border: none;">
#                 <td colspan="3" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 28 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="3" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 20 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.433
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
#         <td style="padding: 0 0.5em 0 1em; text-align: right; border: none;">
#             1.000
#         </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# # Submission

# %%
app_test = pd.read_csv('application_test.csv.zip')

# %%
app_test_features = numeric_features(app_test)
app_test_features = application_composite_features(app_test_features)
app_test_features.shape
# Out:
# (48744, 186)

# %%
submission_record = pd.merge(app_test_features, bureau, on='SK_ID_CURR', how='left')
submission_record = pd.merge(submission_record, bureau_history12m, on='SK_ID_BUREAU', how='left')
submission_record = pd.merge(submission_record, bureau_history60m, on='SK_ID_BUREAU', how='left')
submission_record = pd.merge(submission_record, previous, left_on='SK_ID_CURR', right_on='PREVAPP_SK_ID_CURR', how='left')

missing_columns = list(set(record.columns.values) - set(submission_record.columns.values) - set(['TARGET']))
for col in missing_columns:
    submission_record[col] = 0
    
submission_record.shape
# Out:
# (48744, 248)

# %%
# Create submission dataframe (SKlearn)

X_submission = submission_record.drop(['SK_ID_CURR'], axis=1)
X_submission = X_submission.select_dtypes(exclude='object')
X_submission_imputed = imputer.transform(X_submission)

y_submission = model.predict_proba(X_submission_imputed)
y_submission_proba1 = [a[1] for a in y_submission] #probability for class 1
submission_df = pd.DataFrame(data={'SK_ID_CURR': app_test['SK_ID_CURR'],
                                   'TARGET': y_submission_proba1})

# %%
submission_filename = 'submission06.csv'
submission_message = 'Fourth submission - a few more composite-features'

submission_df.to_csv(submission_filename, index=False)
# !kaggle competitions submit -c home-credit-default-risk -f {submission_filename} -m "{submission_message}"
# Out:
# Successfully submitted to Home Credit Default Risk
